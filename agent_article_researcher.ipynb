# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForCausalLM, pipeline

# %%
# Model names from Hugging Face
EXTRACTION_MODEL_NAME = "facebook/bart-large-cnn"       # For summarization and extraction
GENERATION_MODEL_NAME = "gpt2"                          # For generating counterfactuals (causal model)
WIKIPEDIA_MODEL_NAME = "deepset/roberta-base-squad2"    # For fact-checking against Wikipedia data

# %%
# Load models and tokenizers
extraction_tokenizer = AutoTokenizer.from_pretrained(EXTRACTION_MODEL_NAME)
extraction_model = AutoModelForSeq2SeqLM.from_pretrained(EXTRACTION_MODEL_NAME)

generation_tokenizer = AutoTokenizer.from_pretrained(GENERATION_MODEL_NAME)
generation_model = AutoModelForCausalLM.from_pretrained(GENERATION_MODEL_NAME)  # Fixed: GPT-2 is a causal LM

wikipedia_tokenizer = AutoTokenizer.from_pretrained(WIKIPEDIA_MODEL_NAME)
question_answering = pipeline("question-answering", model=WIKIPEDIA_MODEL_NAME, tokenizer=wikipedia_tokenizer)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
# Extraction pipeline
def extract_statements(article: str, max_length: int = 150):
    """Extract key statements and hypotheses from the article."""
    inputs = extraction_tokenizer.encode(article, return_tensors="pt", truncation=True, max_length=1024)
    summary_ids = extraction_model.generate(
        inputs,
        max_length=max_length,
        min_length=50,
        length_penalty=2.0,
        num_beams=4,
        early_stopping=True
    )
    return extraction_tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# %%
# Generation pipeline
def generate_counterfactuals(statement: str, num_return_sequences: int = 3, max_length: int = 100):
    """Generate counterfactuals or alternative hypotheses from a statement."""
    prompt = f"Given the statement: '{statement}', generate alternative hypotheses or counterfactuals.\n"
    inputs = generation_tokenizer.encode(prompt, return_tensors="pt")
    outputs = generation_model.generate(
        inputs,
        max_length=max_length,
        num_return_sequences=num_return_sequences,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        pad_token_id=generation_tokenizer.eos_token_id  # Prevents tokenization warnings
    )
    return [generation_tokenizer.decode(output, skip_special_tokens=True) for output in outputs]

# %%
# Fact-checking pipeline
def assess_contradiction(counterfactual: str, context: str):
    """Assess if the counterfactual contradicts facts using the Wikipedia-based model."""
    question = f"Is it true that {counterfactual.strip()}?"
    response = question_answering(question=question, context=context)
    return {
        "question": question,
        "answer": response.get('answer', 'N/A'),
        "confidence": response.get('score', 0)
    }

# %%
# Example usage
if __name__ == "__main__":
    article_text = """
    Companies that prioritize customer satisfaction tend to outperform competitors. Innovation in product development is essential for long-term growth.
    Investing in employee training leads to higher productivity. Market diversification can mitigate financial risks.
    """

    print("Extracting statements...")
    extracted = extract_statements(article_text)
    print(f"Extracted Summary: {extracted}\n")

    print("Generating counterfactuals and assessing contradictions...")
    for statement in extracted.split('. '):
        statement = statement.strip()
        if statement:
            counterfactuals = generate_counterfactuals(statement)
            print(f"\nStatement: {statement}")
            for cf in counterfactuals:
                assessment = assess_contradiction(cf, article_text)
                print(f"- Counterfactual: {cf}\n  -> Wikipedia Assessment: {assessment['answer']} (Confidence: {assessment['confidence']:.2f})")
# Out:
# Extracting statements...
# Extracted Summary: Companies that prioritize customer satisfaction tend to outperform competitors. Innovation in product development is essential for long-term growth. Investing in employee training leads to higher productivity. Market diversification can mitigate financial risks for companies that focus on customer satisfaction.
#
# Generating counterfactuals and assessing contradictions...
#
# Statement: Companies that prioritize customer satisfaction tend to outperform competitors
# - Counterfactual: Given the statement: 'Companies that prioritize customer satisfaction tend to outperform competitors', generate alternative hypotheses or counterfactuals.
#
# In conclusion, our findings suggest that the current work may be of little practical use to the business as a whole, and that the business may be unable to effectively manage customer satisfaction in a sustainable way.
#
# There is a substantial need for better management practices in order to better address the growing complexity of the workplace, as well as to address the challenges that arise when
#   -> Wikipedia Assessment:
#     (Confidence: 0.01)
# - Counterfactual: Given the statement: 'Companies that prioritize customer satisfaction tend to outperform competitors', generate alternative hypotheses or counterfactuals.
#
# In other words, if you believe in the value of your company, then you're likely to be better off than a competitor who doesn't.
#
# You could argue that if you're a business owner, you're more likely to be able to achieve a better return on investment by working with your suppliers, using your own expertise, and in a more efficient way
#   -> Wikipedia Assessment:
#     (Confidence: 0.01)
# - Counterfactual: Given the statement: 'Companies that prioritize customer satisfaction tend to outperform competitors', generate alternative hypotheses or counterfactuals.
#
# If we are not prepared to admit that there are other factors that contribute to performance and profitability, then it seems to us that our analysis may be flawed.
#
# The data shows that companies that prioritize customer satisfaction tend to outperform competitors, generate alternative hypotheses or counterfactuals.
#
# The company that maximises shareholder value, and thus is perceived as an
#   -> Wikipedia Assessment:
#     Investing in employee training leads to higher productivity. (Confidence: 0.01)
#
# Statement: Innovation in product development is essential for long-term growth
# - Counterfactual: Given the statement: 'Innovation in product development is essential for long-term growth', generate alternative hypotheses or counterfactuals.
#
# We are a business, not a government.
#
# The fact that the UK is so innovative in its innovation is a fact of life. The UK has been innovating for many years. It has the world's highest GDP, the largest business sector, the world's largest innovation sector and the highest number of patents. We are now making progress in
#   -> Wikipedia Assessment: Companies that prioritize customer satisfaction tend to outperform competitors (Confidence: 0.05)
# - Counterfactual: Given the statement: 'Innovation in product development is essential for long-term growth', generate alternative hypotheses or counterfactuals.
#
# This article was originally published on Medium.
#   -> Wikipedia Assessment: Companies that prioritize customer satisfaction tend to outperform competitors (Confidence: 0.10)
# - Counterfactual: Given the statement: 'Innovation in product development is essential for long-term growth', generate alternative hypotheses or counterfactuals.
#
# The analysis is based on a series of tests of hypotheses, which are then tested in a variety of contexts, including a review of the literature and an analysis of the literature. The conclusions are then tested in a series of experiments, which are then repeated. The results are then published in the peer-reviewed literature.
#
# The main results are summar
#   -> Wikipedia Assessment: Companies that prioritize customer satisfaction tend to outperform competitors (Confidence: 0.10)
#
# Statement: Investing in employee training leads to higher productivity
# - Counterfactual: Given the statement: 'Investing in employee training leads to higher productivity', generate alternative hypotheses or counterfactuals.
#
# The analysis reveals that while the average salary of a non-union employee was $11,000, the average salary of a non-union employee was $20,000. The same study found that, in a year, a non-union employee earned $1,000 less than an average non-union employee. The analysis also found that non-union employees were
#   -> Wikipedia Assessment:
#     Investing in employee training leads to higher productivity. (Confidence: 0.01)
# - Counterfactual: Given the statement: 'Investing in employee training leads to higher productivity', generate alternative hypotheses or counterfactuals.
#
# 'The fact that there are significant differences between the results and the predictions is due to the fact that the differences are not the same. There are many factors involved, including the type of training and the type of data to be analysed.
#
# 'However, the results show that the results of the research are different and that the results are not simply about the results.
#   -> Wikipedia Assessment:
#     Investing in employee training leads to higher productivity. (Confidence: 0.01)
# - Counterfactual: Given the statement: 'Investing in employee training leads to higher productivity', generate alternative hypotheses or counterfactuals.
#
# The second hypothesis is that the work environment is not always conducive to working well. For example, 'Employment-related productivity growth in the workplace can be enhanced through increased productivity, increased productivity with lower turnover, increased productivity with higher productivity, and increased productivity with lower turnover'. In other words, in some contexts, the work environment is conducive to working well.
#
#
#   -> Wikipedia Assessment:
#     Investing in employee training leads to higher productivity. (Confidence: 0.01)
#
# Statement: Market diversification can mitigate financial risks for companies that focus on customer satisfaction.
# - Counterfactual: Given the statement: 'Market diversification can mitigate financial risks for companies that focus on customer satisfaction.', generate alternative hypotheses or counterfactuals.
#
# The following data are derived from the S&P 500 (S&P 500) market index.
#
# 1. Market Index (S&P 500)
#
# Source: S&P 500.com
#
# The S&P 500 index has a broad range of index options (index options are the most common of which are '
#   -> Wikipedia Assessment:
#     Investing in employee training leads to higher productivity. (Confidence: 0.00)
# - Counterfactual: Given the statement: 'Market diversification can mitigate financial risks for companies that focus on customer satisfaction.', generate alternative hypotheses or counterfactuals.
#
# The following are examples of how to do this.
#
# 1. Evaluate the data
#
# The first step is to evaluate the data for your company. This is done by looking at the results of the company's business and its customer satisfaction survey. If the company is not performing as well as expected, you may be able to estimate
#   -> Wikipedia Assessment: Investing in employee training leads to higher productivity. (Confidence: 0.01)
# - Counterfactual: Given the statement: 'Market diversification can mitigate financial risks for companies that focus on customer satisfaction.', generate alternative hypotheses or counterfactuals.
#
# The results are summarized in Table 2.
#
# Table 2. Company Productivity (GDP) Growth Rate (% Change) Change in Productivity (GDP) Growth Rate (% Change) Change in Productivity Growth Rate (% Change) Change in Productivity Growth Rate (% Change) Growth Rate (% Change) Growth Rate
#   -> Wikipedia Assessment:
#     Companies that prioritize customer satisfaction tend to outperform competitors. (Confidence: 0.01)
